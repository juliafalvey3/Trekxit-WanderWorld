# %%
import sqlite3
import pandas as pd
import numpy as np
from gurobipy import *
import datetime
import time

from Wanderworld import *

def generateNewRoute(model):
    route_tuples = []

    for (key,value) in model.LEGS.iteritems():
        if (value.x!=0) and key[0] != key[1]:
            #print key, cost[key], str(key[2])[-2:]
            route_tuples.append(key+(model.COST[key],))

    #print ""

    #print route_tuples
        
    route_tuples = sorted(route_tuples, key=lambda tup: tup[2]) #sorts on date
    route_tuples.append(model.MODEL.objVal) #adds price to list
    route_tuples = tuple(route_tuples) #transforms list to tuple
    
    return route_tuples

    #for i in route_tuples:
        #print i

# %%
conn = sqlite3.connect("flights_final_4_13.db")
c = conn.cursor()
query = c.execute('''SELECT * From flights_min_city ''')
cols = [column[0] for column in query.description]
results = pd.DataFrame.from_records(data = query.fetchall(), columns = cols)

# %%
results[results['origin_city_name']=='Berlin']
# Out:
#          price origin_id destination_id        outbound_date  \
# 912       27.0       AMS            LCY  2017-05-03T00:00:00
# 913       27.0       AMS            LCY  2017-05-09T00:00:00
# 914       27.0       AMS            LCY  2017-05-10T00:00:00
# 915       27.0       AMS            LCY  2017-05-13T00:00:00
# 916       27.0       AMS            LCY  2017-05-16T00:00:00
# 917       27.0       AMS            LCY  2017-05-17T00:00:00
# 918       27.0       AMS            LCY  2017-05-23T00:00:00
# 919       27.0       AMS            LCY  2017-05-30T00:00:00
# 920       27.0       AMS            LCY  2017-05-31T00:00:00
# 921       27.0       AMS            ZRH  2017-05-17T00:00:00
# 922       27.0       AMS            ZRH  2017-05-31T00:00:00
# 1535      29.0       AMS            CPH  2017-05-10T00:00:00
# 1536      29.0       AMS            LCY  2017-05-04T00:00:00
# 1537      29.0       AMS            LCY  2017-05-11T00:00:00
# 1538      29.0       AMS            LCY  2017-05-20T00:00:00
# 1539      29.0       AMS            LCY  2017-05-24T00:00:00
# 1812      31.0       AMS            MAN  2017-05-03T00:00:00
# 1813      31.0       AMS            MAN  2017-05-09T00:00:00
# 1814      31.0       AMS            MAN  2017-05-11T00:00:00
# 1815      31.0       AMS            MAN  2017-05-17T00:00:00
# 1816      31.0       AMS            MAN  2017-05-23T00:00:00
# 1817      31.0       AMS            NCE  2017-05-15T00:00:00
# 1818      31.0       AMS            NCE  2017-05-22T00:00:00
# 1996      32.0       AMS            DUB  2017-05-02T00:00:00
# 1997      32.0       AMS            DUB  2017-05-03T00:00:00
# 1998      32.0       AMS            DUB  2017-05-04T00:00:00
# 1999      32.0       AMS            DUB  2017-05-05T00:00:00
# 2000      32.0       AMS            DUB  2017-05-08T00:00:00
# 2001      32.0       AMS            DUB  2017-05-09T00:00:00
# 2002      32.0       AMS            DUB  2017-05-10T00:00:00
# ...        ...       ...            ...                  ...
# 206546  2826.0       AMS            MTY  2017-05-13T00:00:00
# 206553  2827.0       AMS            GDL  2017-05-01T00:00:00
# 206571  2845.0       AMS            GDL  2017-05-28T00:00:00
# 206572  2846.0       AMS            TIJ  2017-05-18T00:00:00
# 206574  2848.0       AMS            SJD  2017-05-22T00:00:00
# 206578  2853.0       AMS            PLS  2017-05-02T00:00:00
# 206585  2855.0       AMS            MTY  2017-05-24T00:00:00
# 206589  2857.0       AMS            GDL  2017-05-14T00:00:00
# 206590  2857.0       AMS            GDL  2017-05-20T00:00:00
# 206591  2857.0       AMS            GDL  2017-05-21T00:00:00
# 206592  2857.0       AMS            GDL  2017-05-22T00:00:00
# 206593  2857.0       AMS            GDL  2017-05-23T00:00:00
# 206606  2869.0       AMS            YXE  2017-05-29T00:00:00
# 206644  2887.0       AMS            PBC  2017-05-09T00:00:00
# 206653  2889.0       AMS            PBC  2017-05-06T00:00:00
# 206658  2891.0       AMS            PBC  2017-05-14T00:00:00
# 206659  2891.0       AMS            YXE  2017-05-01T00:00:00
# 206660  2891.0       AMS            YXE  2017-05-02T00:00:00
# 206661  2891.0       AMS            YXE  2017-05-18T00:00:00
# 206662  2891.0       AMS            YXE  2017-05-21T00:00:00
# 206663  2892.0       AMS            PBC  2017-05-25T00:00:00
# 206776  2935.0       AMS            PBC  2017-05-31T00:00:00
# 206783  2939.0       AMS            PBC  2017-05-01T00:00:00
# 206784  2939.0       AMS            PBC  2017-05-02T00:00:00
# 206903  3035.0       AMS            PBC  2017-05-29T00:00:00
# 207282  4963.0       AMS            BZE  2017-05-05T00:00:00
# 207285  4993.0       AMS            ALA  2017-05-24T00:00:00
# 207296  5480.0       AMS            YOW  2017-05-25T00:00:00
# 207354  8123.0       AMS            PPT  2017-05-15T00:00:00
# 207355  8128.0       AMS            PPT  2017-05-01T00:00:00
#
#                inbound_date currency origin_city_name origin_country_name  \
# 912     2017-05-03T00:00:00      USD        Amsterdam         Netherlands
# 913     2017-05-09T00:00:00      USD        Amsterdam         Netherlands
# 914     2017-05-10T00:00:00      USD        Amsterdam         Netherlands
# 915     2017-05-13T00:00:00      USD        Amsterdam         Netherlands
# 916     2017-05-16T00:00:00      USD        Amsterdam         Netherlands
# 917     2017-05-17T00:00:00      USD        Amsterdam         Netherlands
# 918     2017-05-23T00:00:00      USD        Amsterdam         Netherlands
# 919     2017-05-30T00:00:00      USD        Amsterdam         Netherlands
# 920     2017-05-31T00:00:00      USD        Amsterdam         Netherlands
# 921     2017-05-17T00:00:00      USD        Amsterdam         Netherlands
# 922     2017-05-31T00:00:00      USD        Amsterdam         Netherlands
# 1535    2017-05-10T00:00:00      USD        Amsterdam         Netherlands
# 1536    2017-05-04T00:00:00      USD        Amsterdam         Netherlands
# 1537    2017-05-11T00:00:00      USD        Amsterdam         Netherlands
# 1538    2017-05-20T00:00:00      USD        Amsterdam         Netherlands
# 1539    2017-05-24T00:00:00      USD        Amsterdam         Netherlands
# 1812    2017-05-03T00:00:00      USD        Amsterdam         Netherlands
# 1813    2017-05-09T00:00:00      USD        Amsterdam         Netherlands
# 1814    2017-05-11T00:00:00      USD        Amsterdam         Netherlands
# 1815    2017-05-17T00:00:00      USD        Amsterdam         Netherlands
# 1816    2017-05-23T00:00:00      USD        Amsterdam         Netherlands
# 1817    2017-05-15T00:00:00      USD        Amsterdam         Netherlands
# 1818    2017-05-22T00:00:00      USD        Amsterdam         Netherlands
# 1996    2017-05-02T00:00:00      USD        Amsterdam         Netherlands
# 1997    2017-05-03T00:00:00      USD        Amsterdam         Netherlands
# 1998    2017-05-04T00:00:00      USD        Amsterdam         Netherlands
# 1999    2017-05-05T00:00:00      USD        Amsterdam         Netherlands
# 2000    2017-05-08T00:00:00      USD        Amsterdam         Netherlands
# 2001    2017-05-09T00:00:00      USD        Amsterdam         Netherlands
# 2002    2017-05-10T00:00:00      USD        Amsterdam         Netherlands
# ...                     ...      ...              ...                 ...
# 206546  2017-05-13T00:00:00      USD        Amsterdam         Netherlands
# 206553  2017-05-01T00:00:00      USD        Amsterdam         Netherlands
# 206571  2017-05-28T00:00:00      USD        Amsterdam         Netherlands
# 206572  2017-05-18T00:00:00      USD        Amsterdam         Netherlands
# 206574  2017-05-22T00:00:00      USD        Amsterdam         Netherlands
# 206578  2017-05-02T00:00:00      USD        Amsterdam         Netherlands
# 206585  2017-05-24T00:00:00      USD        Amsterdam         Netherlands
# 206589  2017-05-14T00:00:00      USD        Amsterdam         Netherlands
# 206590  2017-05-20T00:00:00      USD        Amsterdam         Netherlands
# 206591  2017-05-21T00:00:00      USD        Amsterdam         Netherlands
# 206592  2017-05-22T00:00:00      USD        Amsterdam         Netherlands
# 206593  2017-05-23T00:00:00      USD        Amsterdam         Netherlands
# 206606  2017-05-29T00:00:00      USD        Amsterdam         Netherlands
# 206644  2017-05-09T00:00:00      USD        Amsterdam         Netherlands
# 206653  2017-05-06T00:00:00      USD        Amsterdam         Netherlands
# 206658  2017-05-14T00:00:00      USD        Amsterdam         Netherlands
# 206659  2017-05-01T00:00:00      USD        Amsterdam         Netherlands
# 206660  2017-05-02T00:00:00      USD        Amsterdam         Netherlands
# 206661  2017-05-18T00:00:00      USD        Amsterdam         Netherlands
# 206662  2017-05-21T00:00:00      USD        Amsterdam         Netherlands
# 206663  2017-05-25T00:00:00      USD        Amsterdam         Netherlands
# 206776  2017-05-31T00:00:00      USD        Amsterdam         Netherlands
# 206783  2017-05-01T00:00:00      USD        Amsterdam         Netherlands
# 206784  2017-05-02T00:00:00      USD        Amsterdam         Netherlands
# 206903  2017-05-29T00:00:00      USD        Amsterdam         Netherlands
# 207282  2017-05-05T00:00:00      USD        Amsterdam         Netherlands
# 207285  2017-05-24T00:00:00      USD        Amsterdam         Netherlands
# 207296  2017-05-25T00:00:00      USD        Amsterdam         Netherlands
# 207354  2017-05-15T00:00:00      USD        Amsterdam         Netherlands
# 207355  2017-05-01T00:00:00      USD        Amsterdam         Netherlands
#
#        destination_city_name  destination_country_name direct  \
# 912                   London            United Kingdom      1
# 913                   London            United Kingdom      1
# 914                   London            United Kingdom      1
# 915                   London            United Kingdom      1
# 916                   London            United Kingdom      1
# 917                   London            United Kingdom      1
# 918                   London            United Kingdom      1
# 919                   London            United Kingdom      1
# 920                   London            United Kingdom      1
# 921                   Zurich               Switzerland      1
# 922                   Zurich               Switzerland      1
# 1535              Copenhagen                   Denmark      1
# 1536                  London            United Kingdom      1
# 1537                  London            United Kingdom      1
# 1538                  London            United Kingdom      1
# 1539                  London            United Kingdom      1
# 1812              Manchester            United Kingdom      1
# 1813              Manchester            United Kingdom      1
# 1814              Manchester            United Kingdom      1
# 1815              Manchester            United Kingdom      1
# 1816              Manchester            United Kingdom      1
# 1817                    Nice                    France      1
# 1818                    Nice                    France      1
# 1996                  Dublin                   Ireland      1
# 1997                  Dublin                   Ireland      1
# 1998                  Dublin                   Ireland      1
# 1999                  Dublin                   Ireland      1
# 2000                  Dublin                   Ireland      1
# 2001                  Dublin                   Ireland      1
# 2002                  Dublin                   Ireland      1
# ...                      ...                       ...    ...
# 206546             Monterrey                    Mexico      0
# 206553           Guadalajara                    Mexico      0
# 206571           Guadalajara                    Mexico      0
# 206572               Tijuana                    Mexico      0
# 206574         San Jose Cabo                    Mexico      0
# 206578        Providenciales  Turks and Caicos Islands      0
# 206585             Monterrey                    Mexico      0
# 206589           Guadalajara                    Mexico      0
# 206590           Guadalajara                    Mexico      0
# 206591           Guadalajara                    Mexico      0
# 206592           Guadalajara                    Mexico      0
# 206593           Guadalajara                    Mexico      0
# 206606             Saskatoon                    Canada      0
# 206644                Puebla                    Mexico      0
# 206653                Puebla                    Mexico      0
# 206658                Puebla                    Mexico      0
# 206659             Saskatoon                    Canada      0
# 206660             Saskatoon                    Canada      0
# 206661             Saskatoon                    Canada      0
# 206662             Saskatoon                    Canada      0
# 206663                Puebla                    Mexico      0
# 206776                Puebla                    Mexico      0
# 206783                Puebla                    Mexico      0
# 206784                Puebla                    Mexico      0
# 206903                Puebla                    Mexico      0
# 207282           Belize City                    Belize      0
# 207285                Almaty                Kazakhstan      0
# 207296                Ottawa                    Canada      0
# 207354               Papeete          French Polynesia      0
# 207355               Papeete          French Polynesia      0
#
#             carrier_name carrier_id skyscanner_code  \
# 912                Flybe        885             LCY
# 913                Flybe        885             LCY
# 914                Flybe        885             LCY
# 915                Flybe        885             LCY
# 916                Flybe        885             LCY
# 917                Flybe        885             LCY
# 918                Flybe        885             LCY
# 919                Flybe        885             LCY
# 920                Flybe        885             LCY
# 921     Vueling Airlines          7             ZRH
# 922     Vueling Airlines          7             ZRH
# 1535           Norwegian       1001             CPH
# 1536               Flybe        885             LCY
# 1537               Flybe        885             LCY
# 1538               Flybe        885             LCY
# 1539               Flybe        885             LCY
# 1812    Vueling Airlines          7             MAN
# 1813    Vueling Airlines          7             MAN
# 1814    Vueling Airlines          7             MAN
# 1815    Vueling Airlines          7             MAN
# 1816    Vueling Airlines          7             MAN
# 1817           Norwegian       1001             NCE
# 1818           Norwegian       1001             NCE
# 1996          Aer Lingus       1033             DUB
# 1997          Aer Lingus       1033             DUB
# 1998          Aer Lingus       1033             DUB
# 1999          Aer Lingus       1033             DUB
# 2000          Aer Lingus       1033             DUB
# 2001          Aer Lingus       1033             DUB
# 2002          Aer Lingus       1033             DUB
# ...                  ...        ...             ...
# 206546        Aeromexico        845             MTY
# 206553        Aeromexico        845             GDL
# 206571        Aeromexico        845             GDL
# 206572               KLM       1324             TIJ
# 206574        Aeromexico        845             SJD
# 206578   British Airways        881             PLS
# 206585        Aeromexico        845             MTY
# 206589        Aeromexico        845             GDL
# 206590        Aeromexico        845             GDL
# 206591        Aeromexico        845             GDL
# 206592        Aeromexico        845             GDL
# 206593        Aeromexico        845             GDL
# 206606               KLM       1324             YXE
# 206644            United       1793             PBC
# 206653            United       1793             PBC
# 206658            United       1793             PBC
# 206659               KLM       1324             YXE
# 206660               KLM       1324             YXE
# 206661               KLM       1324             YXE
# 206662               KLM       1324             YXE
# 206663            United       1793             PBC
# 206776            United       1793             PBC
# 206783            United       1793             PBC
# 206784            United       1793             PBC
# 206903            United       1793             PBC
# 207282            United       1793             BZE
# 207285  Pegasus Airlines       1161             AMS
# 207296            Condor        981             YOW
# 207354        Air France        838             PPT
# 207355        Air France        838             PPT
#
#                     date_collected
# 912     2017-04-13 10:06:48.991276
# 913     2017-04-13 10:06:48.991276
# 914     2017-04-13 01:15:46.819594
# 915     2017-04-13 01:15:46.819594
# 916     2017-04-13 01:15:46.819594
# 917     2017-04-13 01:15:46.819594
# 918     2017-04-13 01:15:46.819594
# 919     2017-04-13 10:06:48.991276
# 920     2017-04-13 01:15:46.819594
# 921     2017-04-13 01:15:46.819594
# 922     2017-04-13 01:15:46.819594
# 1535    2017-04-13 09:47:44.024964
# 1536    2017-04-13 01:15:46.819594
# 1537    2017-04-13 01:15:46.819594
# 1538    2017-04-13 01:15:46.819594
# 1539    2017-04-13 10:06:48.991276
# 1812    2017-04-13 01:15:46.819594
# 1813    2017-04-13 01:15:46.819594
# 1814    2017-04-13 01:15:46.819594
# 1815    2017-04-13 18:44:21.269730
# 1816    2017-04-13 09:47:44.024964
# 1817    2017-04-13 01:15:46.819594
# 1818    2017-04-13 01:15:46.819594
# 1996    2017-04-13 01:15:46.819594
# 1997    2017-04-13 01:15:46.819594
# 1998    2017-04-13 01:15:46.819594
# 1999    2017-04-13 01:15:46.819594
# 2000    2017-04-13 01:15:46.819594
# 2001    2017-04-13 01:15:46.819594
# 2002    2017-04-13 01:15:46.819594
# ...                            ...
# 206546  2017-04-13 01:15:46.819594
# 206553  2017-04-13 01:15:46.819594
# 206571  2017-04-13 01:15:46.819594
# 206572  2017-04-13 01:15:46.819594
# 206574  2017-04-13 01:15:46.819594
# 206578  2017-04-13 01:15:46.819594
# 206585  2017-04-13 01:15:46.819594
# 206589  2017-04-13 01:15:46.819594
# 206590  2017-04-13 10:06:48.991276
# 206591  2017-04-13 01:15:46.819594
# 206592  2017-04-13 01:15:46.819594
# 206593  2017-04-13 01:15:46.819594
# 206606  2017-04-13 01:15:46.819594
# 206644  2017-04-13 01:15:46.819594
# 206653  2017-04-13 01:15:46.819594
# 206658  2017-04-13 01:15:46.819594
# 206659  2017-04-13 01:15:46.819594
# 206660  2017-04-13 01:15:46.819594
# 206661  2017-04-13 01:15:46.819594
# 206662  2017-04-13 01:15:46.819594
# 206663  2017-04-13 10:06:48.991276
# 206776  2017-04-13 01:15:46.819594
# 206783  2017-04-13 01:15:46.819594
# 206784  2017-04-13 01:15:46.819594
# 206903  2017-04-13 01:15:46.819594
# 207282  2017-04-13 01:15:46.819594
# 207285  2017-04-13 01:15:46.819594
# 207296  2017-04-13 01:15:46.819594
# 207354  2017-04-13 01:15:46.819594
# 207355  2017-04-13 01:15:46.819594
#
# [6860 rows x 15 columns]

# %%
if __name__ == "__main__":
	conn = sqlite3.connect("flight_sample.db")
	c = conn.cursor()
	query = c.execute('''SELECT * From flights ''')
	cols = [column[0] for column in query.description]
	results = pd.DataFrame.from_records(data = query.fetchall(), columns = cols)

	# results.to_csv('flights.csv')

	#df = pd.read_sql_query("SELECT * FROM table_name", conn)
	#dat = sqlite3.connect("flight.db")
	#query = dat.execute("SELECT * From flight")
	#cols = [column[0] for column in query.description]
	#results= pd.DataFrame.from_records(data = query.fetchall(), columns = cols)


	user_start = '2017-05-01T00:00:00'
	user_end = '2017-05-31T00:00:00'
	origins = results['origin_id'].unique()
	city_list = origins
	num_days = 15
	min_days = 2
	origin = 'ATL'
	#print city_list


	Example = WanderWorld(results)
	Example.inputTimeFrame(user_start, user_end, city_list, num_days, min_days, origin)
	Example.createInputDicts()
	Example.buildAndSolveModel()

	routes = []

	for model in Example.modelList:
		routes.append(generateNewRoute(model))

	#for model in Example.modelList:
    	#in main loop:
    	#routes.append(generateNewRoute(model))
    	#print routes
		#print routes

    	#sort and slice at very end:
	sorted_routes = sorted(routes, key=lambda tup: tup[-1]) #sorts on total price
	final_results = sorted_routes[0:4] #or however many we want to return

	# print 'length:',len(final_results)
	# print final_results

	#import csv
	#with open('final_result.csv', 'wb') as myfile:
	#	wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
	#	wr.writerow(final_results)
    
	outputDict = {}
	outputDict['TripID'] = []
	outputDict['Seq'] = []
	outputDict['Origin'] = []
	outputDict['Dest'] = []
	outputDict['Price'] = []
	outputDict['Date1'] = []
	outputDict['Date2'] = []
	outputDict['Total Price'] = [] 
    
	for tripID, route in enumerate(final_results):
		#print route
		totalPrice = route[-1]
		for seq, flight in enumerate(route): 
			if(flight==totalPrice):
				break
			outputDict['TripID'].append(tripID)
			outputDict['Seq'].append(seq)
			outputDict['Origin'].append(flight[0])
			outputDict['Dest'].append(flight[1])
			outputDict['Price'].append(flight[4])
			departDate_String, arriDate_String = extractRealDate(flight)
			outputDict['Date1'].append(departDate_String)
			outputDict['Date2'].append(arriDate_String)
			outputDict['Total_Price'].append(totalPrice) 
            
	print outputDict
	outputDF = pd.DataFrame.from_dict(outputDict)
	print outputDF
    
	outputDF.to_csv('niceOutput.csv')
# Out:
# 2017-05-01
# 2017-05-02
# 2017-05-03
# 2017-05-04
# 2017-05-05
# 2017-05-06
# 2017-05-07
# 2017-05-08
# 2017-05-09
# 2017-05-10
# 2017-05-11
# 2017-05-12
# 2017-05-13
# 2017-05-14
# 2017-05-15
# 2017-05-16
# Optimize a model with 54 rows, 125 columns and 414 nonzeros
# Coefficient statistics:
#   Matrix range    [1e+00, 1e+00]
#   Objective range [3e+01, 3e+03]
#   Bounds range    [1e+00, 1e+00]
#   RHS range       [1e+00, 1e+01]
# Presolve removed 10 rows and 27 columns
# Presolve time: 0.01s
# Presolved: 44 rows, 98 columns, 332 nonzeros
# Variable types: 0 continuous, 98 integer (98 binary)
# Found heuristic solution: objective 4051.0000000
#
# Root relaxation: objective 2.092061e+03, 59 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2092.06061    0   26 4051.00000 2092.06061  48.4%     -    0s
# H    0     0                    2106.0000000 2092.06061  0.66%     -    0s
#      0     0     cutoff    0      2106.00000 2105.00211  0.05%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Zero half: 2
#
# Explored 0 nodes (60 simplex iterations) in 0.06 seconds
# Thread count was 4 (of 4 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.106000000000e+03, best bound 2.106000000000e+03, gap 0.0%
# Optimize a model with 54 rows, 125 columns and 414 nonzeros
# Coefficient statistics:
#   Matrix range    [1e+00, 1e+00]
#   Objective range [3e+01, 3e+03]
#   Bounds range    [1e+00, 1e+00]
#   RHS range       [1e+00, 1e+01]
# Presolve removed 10 rows and 27 columns
# Presolve time: 0.01s
# Presolved: 44 rows, 98 columns, 332 nonzeros
# Variable types: 0 continuous, 98 integer (98 binary)
# Found heuristic solution: objective 4067.0000000
# Found heuristic solution: objective 3840.0000000
#
# Root relaxation: objective 1.183825e+03, 65 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1183.82500    0   30 3840.00000 1183.82500  69.2%     -    0s
# *    0     0               0    1255.0000000 1255.00000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Zero half: 2
#
# Explored 0 nodes (74 simplex iterations) in 0.05 seconds
# Thread count was 4 (of 4 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.255000000000e+03, best bound 1.255000000000e+03, gap 0.0%
# Optimize a model with 54 rows, 124 columns and 411 nonzeros
# Coefficient statistics:
#   Matrix range    [1e+00, 1e+00]
#   Objective range [3e+01, 3e+03]
#   Bounds range    [1e+00, 1e+00]
#   RHS range       [1e+00, 1e+01]
# Found heuristic solution: objective 3740
# Presolve removed 32 rows and 83 columns
# Presolve time: 0.01s
# Presolved: 22 rows, 41 columns, 123 nonzeros
# Variable types: 0 continuous, 41 integer (41 binary)
#
# Root relaxation: objective 3.719667e+03, 19 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3719.66667    0    6 3740.00000 3719.66667  0.54%     -    0s
# H    0     0                    3725.0000000 3719.66667  0.14%     -    0s
# H    0     0                    3721.0000000 3719.66667  0.04%     -    0s
#
# Explored 0 nodes (19 simplex iterations) in 0.04 seconds
# Thread count was 4 (of 4 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.721000000000e+03, best bound 3.721000000000e+03, gap 0.0%
# Optimize a model with 54 rows, 124 columns and 411 nonzeros
# Coefficient statistics:
#   Matrix range    [1e+00, 1e+00]
#   Objective range [3e+01, 3e+03]
#   Bounds range    [1e+00, 1e+00]
#   RHS range       [1e+00, 1e+01]
# Presolve removed 32 rows and 84 columns
# Presolve time: 0.01s
# Presolved: 22 rows, 40 columns, 119 nonzeros
# Variable types: 0 continuous, 40 integer (40 binary)
# Found heuristic solution: objective 3708.0000000
#
# Root relaxation: objective 3.679250e+03, 20 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3679.25000    0    6 3708.00000 3679.25000  0.78%     -    0s
# H    0     0                    3686.0000000 3679.25000  0.18%     -    0s
# H    0     0                    3683.0000000 3679.25000  0.10%     -    0s
#
# Explored 0 nodes (20 simplex iterations) in 0.05 seconds
# Thread count was 4 (of 4 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.683000000000e+03, best bound 3.683000000000e+03, gap 0.0%
# Optimize a model with 54 rows, 124 columns and 411 nonzeros
# Coefficient statistics:
#   Matrix range    [1e+00, 1e+00]
#   Objective range [3e+01, 3e+03]
#   Bounds range    [1e+00, 1e+00]
#   RHS range       [1e+00, 1e+01]
# Found heuristic solution: objective 3883
# Presolve removed 32 rows and 82 columns
# Presolve time: 0.01s
# Presolved: 22 rows, 42 columns, 127 nonzeros
# Variable types: 0 continuous, 42 integer (42 binary)
#
# Root relaxation: objective 3.844000e+03, 13 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3844.00000    0   10 3883.00000 3844.00000  1.00%     -    0s
# H    0     0                    3853.0000000 3844.00000  0.23%     -    0s
# H    0     0                    3852.0000000 3844.00000  0.21%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   GUB cover: 1
#   Mod-K: 1
#
# Explored 0 nodes (14 simplex iterations) in 0.05 seconds
# Thread count was 4 (of 4 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.852000000000e+03, best bound 3.852000000000e+03, gap 0.0%
# Optimize a model with 54 rows, 124 columns and 411 nonzeros
# Coefficient statistics:
#   Matrix range    [1e+00, 1e+00]
#   Objective range [2e+01, 3e+03]
#   Bounds range    [1e+00, 1e+00]
#   RHS range       [1e+00, 1e+01]
# Presolve removed 32 rows and 83 columns
# Presolve time: 0.01s
# Presolved: 22 rows, 41 columns, 123 nonzeros
# Variable types: 0 continuous, 41 integer (41 binary)
# Found heuristic solution: objective 3868.0000000
# Found heuristic solution: objective 3851.0000000
# Found heuristic solution: objective 3841.0000000
#
# Root relaxation: cutoff, 1 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      3841.00000 3840.00384  0.03%     -    0s
#
# Explored 0 nodes (1 simplex iterations) in 0.04 seconds
# Thread count was 4 (of 4 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.841000000000e+03, best bound 3.841000000000e+03, gap 0.0%
# Optimize a model with 54 rows, 124 columns and 411 nonzeros
# Coefficient statistics:
#   Matrix range    [1e+00, 1e+00]
#   Objective range [2e+01, 3e+03]
#   Bounds range    [1e+00, 1e+00]
#   RHS range       [1e+00, 1e+01]
# Presolve removed 32 rows and 84 columns
# Presolve time: 0.01s
# Presolved: 22 rows, 40 columns, 119 nonzeros
# Variable types: 0 continuous, 40 integer (40 binary)
# Found heuristic solution: objective 3714.0000000
# Found heuristic solution: objective 3693.0000000
#
# Root relaxation: objective 3.683000e+03, 15 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    3683.0000000 3683.00000  0.00%     -    0s
#
# Explored 0 nodes (15 simplex iterations) in 0.04 seconds
# Thread count was 4 (of 4 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.683000000000e+03, best bound 3.683000000000e+03, gap 0.0%
# Optimize a model with 54 rows, 125 columns and 414 nonzeros
# Coefficient statistics:
#   Matrix range    [1e+00, 1e+00]
#   Objective range [2e+01, 3e+03]
#   Bounds range    [1e+00, 1e+00]
#   RHS range       [1e+00, 1e+01]
# Found heuristic solution: objective 2780
# Presolve removed 12 rows and 43 columns
# Presolve time: 0.01s
# Presolved: 42 rows, 82 columns, 271 nonzeros
# Variable types: 0 continuous, 82 integer (82 binary)
#
# Root relaxation: objective 2.591000e+03, 64 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2591.00000    0   27 2780.00000 2591.00000  6.80%     -    0s
# H    0     0                    2779.0000000 2591.00000  6.77%     -    0s
# *    0     0               0    2758.0000000 2758.00000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Clique: 8
#   MIR: 1
#   Zero half: 1
#
# Explored 0 nodes (73 simplex iterations) in 0.10 seconds
# Thread count was 4 (of 4 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.758000000000e+03, best bound 2.758000000000e+03, gap 0.0%
# Optimize a model with 54 rows, 124 columns and 411 nonzeros
# Coefficient statistics:
#   Matrix range    [1e+00, 1e+00]
#   Objective range [2e+01, 3e+03]
#   Bounds range    [1e+00, 1e+00]
#   RHS range       [1e+00, 1e+01]
# Found heuristic solution: objective 4828
# Presolve removed 32 rows and 82 columns
# Presolve time: 0.01s
# Presolved: 22 rows, 42 columns, 127 nonzeros
# Variable types: 0 continuous, 42 integer (42 binary)
#
# Root relaxation: objective 3.871000e+03, 6 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    3871.0000000 3871.00000  0.00%     -    0s
#
# Explored 0 nodes (6 simplex iterations) in 0.03 seconds
# Thread count was 4 (of 4 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.871000000000e+03, best bound 3.871000000000e+03, gap 0.0%
# Optimize a model with 54 rows, 124 columns and 411 nonzeros
# Coefficient statistics:
#   Matrix range    [1e+00, 1e+00]
#   Objective range [2e+01, 3e+03]
#   Bounds range    [1e+00, 1e+00]
#   RHS range       [1e+00, 1e+01]
# Presolve removed 32 rows and 83 columns
# Presolve time: 0.01s
# Presolved: 22 rows, 41 columns, 123 nonzeros
# Variable types: 0 continuous, 41 integer (41 binary)
# Found heuristic solution: objective 3798.0000000
#
# Root relaxation: objective 3.789000e+03, 5 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    3789.0000000 3789.00000  0.00%     -    0s
#
# Explored 0 nodes (5 simplex iterations) in 0.04 seconds
# Thread count was 4 (of 4 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.789000000000e+03, best bound 3.789000000000e+03, gap 0.0%
# Optimize a model with 54 rows, 124 columns and 411 nonzeros
# Coefficient statistics:
#   Matrix range    [1e+00, 1e+00]
#   Objective range [2e+01, 3e+03]
#   Bounds range    [1e+00, 1e+00]
#   RHS range       [1e+00, 1e+01]
# Presolve removed 32 rows and 84 columns
# Presolve time: 0.01s
# Presolved: 22 rows, 40 columns, 119 nonzeros
# Variable types: 0 continuous, 40 integer (40 binary)
# Found heuristic solution: objective 3767.0000000
#
# Root relaxation: objective 3.762000e+03, 11 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    3762.0000000 3762.00000  0.00%     -    0s
#
# Explored 0 nodes (11 simplex iterations) in 0.04 seconds
# Thread count was 4 (of 4 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.762000000000e+03, best bound 3.762000000000e+03, gap 0.0%
# Optimize a model with 54 rows, 124 columns and 411 nonzeros
# Coefficient statistics:
#   Matrix range    [1e+00, 1e+00]
#   Objective range [2e+01, 3e+03]
#   Bounds range    [1e+00, 1e+00]
#   RHS range       [1e+00, 1e+01]
# Found heuristic solution: objective 3964
# Presolve removed 32 rows and 83 columns
# Presolve time: 0.01s
# Presolved: 22 rows, 41 columns, 123 nonzeros
# Variable types: 0 continuous, 41 integer (41 binary)
#
# Root relaxation: objective 3.908000e+03, 9 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    3908.0000000 3908.00000  0.00%     -    0s
#
# Explored 0 nodes (9 simplex iterations) in 0.04 seconds
# Thread count was 4 (of 4 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.908000000000e+03, best bound 3.908000000000e+03, gap 0.0%
# Optimize a model with 54 rows, 124 columns and 411 nonzeros
# Coefficient statistics:
#   Matrix range    [1e+00, 1e+00]
#   Objective range [2e+01, 7e+03]
#   Bounds range    [1e+00, 1e+00]
#   RHS range       [1e+00, 1e+01]
# Found heuristic solution: objective 5988
# Presolve removed 32 rows and 84 columns
# Presolve time: 0.01s
# Presolved: 22 rows, 40 columns, 119 nonzeros
# Variable types: 0 continuous, 40 integer (40 binary)
#
# Root relaxation: objective 5.920000e+03, 7 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5920.0000000 5920.00000  0.00%     -    0s
#
# Explored 0 nodes (7 simplex iterations) in 0.03 seconds
# Thread count was 4 (of 4 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.920000000000e+03, best bound 5.920000000000e+03, gap 0.0%
# Optimize a model with 54 rows, 124 columns and 411 nonzeros
# Coefficient statistics:
#   Matrix range    [1e+00, 1e+00]
#   Objective range [2e+01, 3e+03]
#   Bounds range    [1e+00, 1e+00]
#   RHS range       [1e+00, 1e+01]
# Presolve removed 32 rows and 83 columns
# Presolve time: 0.01s
# Presolved: 22 rows, 41 columns, 123 nonzeros
# Variable types: 0 continuous, 41 integer (41 binary)
# Found heuristic solution: objective 3868.0000000
# Found heuristic solution: objective 3853.0000000
#
# Root relaxation: objective 3.829200e+03, 13 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3829.20000    0   10 3853.00000 3829.20000  0.62%     -    0s
#
# Cutting planes:
#   Clique: 1
#
# Explored 0 nodes (13 simplex iterations) in 0.05 seconds
# Thread count was 4 (of 4 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.853000000000e+03, best bound 3.853000000000e+03, gap 0.0%
# Optimize a model with 54 rows, 124 columns and 411 nonzeros
# Coefficient statistics:
#   Matrix range    [1e+00, 1e+00]
#   Objective range [2e+01, 3e+03]
#   Bounds range    [1e+00, 1e+00]
#   RHS range       [1e+00, 1e+01]
# Presolve removed 32 rows and 82 columns
# Presolve time: 0.01s
# Presolved: 22 rows, 42 columns, 127 nonzeros
# Variable types: 0 continuous, 42 integer (42 binary)
# Found heuristic solution: objective 3714.0000000
# Found heuristic solution: objective 3690.0000000
# Found heuristic solution: objective 3667.0000000
#
# Root relaxation: cutoff, 4 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      3667.00000 3666.00367  0.03%     -    0s
#
# Explored 0 nodes (4 simplex iterations) in 0.04 seconds
# Thread count was 4 (of 4 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.667000000000e+03, best bound 3.667000000000e+03, gap 0.0%
# Optimize a model with 54 rows, 124 columns and 411 nonzeros
# Coefficient statistics:
#   Matrix range    [1e+00, 1e+00]
#   Objective range [2e+01, 3e+03]
#   Bounds range    [1e+00, 1e+00]
#   RHS range       [1e+00, 1e+01]
# Presolve removed 32 rows and 83 columns
# Presolve time: 0.01s
# Presolved: 22 rows, 41 columns, 123 nonzeros
# Variable types: 0 continuous, 41 integer (41 binary)
# Found heuristic solution: objective 3683.0000000
# Found heuristic solution: objective 3663.0000000
#
# Root relaxation: objective 3.660000e+03, 7 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    3660.0000000 3660.00000  0.00%     -    0s
#
# Explored 0 nodes (7 simplex iterations) in 0.04 seconds
# Thread count was 4 (of 4 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.660000000000e+03, best bound 3.660000000000e+03, gap 0.0%
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-8d70ca635791> in <module>()
#      77                         outputDict['Date1'].append(departDate_String)
#      78                         outputDict['Date2'].append(arriDate_String)
# ---> 79                         outputDict['Total_Price'].append(totalPrice)
#      80
#      81         print outputDict
#
# KeyError: 'Total_Price'

# %%
def extractRealDate(flight):
    departDate = flight[2]
    arriDate = flight[3]
    departDate_String = departDate.strftime("%Y-%m-%d")# %H:%M:%S")
    arriDate_String = arriDate.strftime("%Y-%m-%d")
    
    return departDate_String, arriDate_String
